# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
DATAROOT = "val"
os.listdir(DATAROOT)
# Out:
# ['2022-05-11_FIRE-SGL-111-Confluence_M600',
#  '2021-11-08_FIRE-SGL-174-Rossiter_M100',
#  '2022-11-08_FIRE-SGL-108-Reade-Township_M600']

# %% [markdown]
# - seek cameras
# - FLIR cameras
#
#
# per folder:
# - how many total boxes per class?
# - what percentage of detections to no detections?
# - visualization of detection number over time?
# - size statistics of boxes?
# - height of UAS?

# %% [markdown]
# how to ensure similar distributions of fire vs no fire?

# %% [markdown]
# ```
# WIT-UAV-Dataset
# ├── 2021-11-08_FIRE-SGL-174-Rossiter_M100-Data-Collect
# │   ├── 2021-11-07_19-19-31_dji_sdk_and_thermal.repaired
# │   ├── 2021-11-07_19-19-36_dji_sdk_and_thermal.repaired
# │   ├── 2021-11-07_19-19-54_dji_sdk_and_thermal
# │   └── 2021-11-07_19-20-26_dji_sdk_and_thermal.repaired
# ├── 2022-05-11_FIRE-SGL-111-Confluence_M600-Data-Collect
# │   ├── seek_displayImage
# │   │   ├── 2022-04-27_00-18-06
# │   │   ├── 2022-04-27_00-18-47
# │   │   └── 2022-04-27_00-24-53
# │   └── thermal_1_image_rect
# │       ├── 2022-04-27_00-18-06
# │       ├── 2022-04-27_00-18-47
# │       └── 2022-04-27_00-24-53
# └── 2022-11-08_FIRE-SGL-108-Reade-Township_M600-Coverage-Test
#     ├── 2022-11-08_13-15-55_dji_sdk_and_thermal
#     ├── 2022-11-08_14-13-12_dji_sdk_and_thermal
#     └── 2022-11-08_14-40-21_dji_sdk_and_thermal.kinda-repaired-images-only_labeled
# ```

# %%
list_of_runs = []
for dirpath, dirnames, filenames in os.walk(DATAROOT):
    if not dirnames:
        list_of_runs.append(dirpath)
        print(dirpath, "has 0 subdirectories and", len(filenames), "files")
list_of_runs = sorted(list_of_runs)
# Out:
# val/2022-05-11_FIRE-SGL-111-Confluence_M600/2022-04-27_00-24-53_flir has 0 subdirectories and 181 files
# val/2022-05-11_FIRE-SGL-111-Confluence_M600/2022-04-27_00-24-53_seek has 0 subdirectories and 203 files
# val/2022-05-11_FIRE-SGL-111-Confluence_M600/2022-04-27_00-18-47_seek has 0 subdirectories and 329 files
# val/2022-05-11_FIRE-SGL-111-Confluence_M600/2022-04-27_00-18-06_flir has 0 subdirectories and 176 files
# val/2022-05-11_FIRE-SGL-111-Confluence_M600/2022-04-27_00-18-06_seek has 0 subdirectories and 240 files
# val/2022-05-11_FIRE-SGL-111-Confluence_M600/2022-04-27_00-18-47_flir has 0 subdirectories and 183 files
# val/2021-11-08_FIRE-SGL-174-Rossiter_M100/2021-11-07_19-19-36_flir has 0 subdirectories and 75 files
# val/2021-11-08_FIRE-SGL-174-Rossiter_M100/2021-11-07_19-20-26_flir has 0 subdirectories and 32 files
# val/2021-11-08_FIRE-SGL-174-Rossiter_M100/2021-11-07_19-19-31_flir has 0 subdirectories and 60 files
# val/2021-11-08_FIRE-SGL-174-Rossiter_M100/2021-11-07_19-19-54_flir has 0 subdirectories and 8 files
# val/2022-11-08_FIRE-SGL-108-Reade-Township_M600/2022-11-08_14-13-12_seek has 0 subdirectories and 28 files
# val/2022-11-08_FIRE-SGL-108-Reade-Township_M600/2022-11-08_13-15-55_seek has 0 subdirectories and 36 files
# val/2022-11-08_FIRE-SGL-108-Reade-Township_M600/2022-11-08_14-40-21_seek has 0 subdirectories and 88 files

# %%
list_of_runs
# Out:
# ['val/2021-11-08_FIRE-SGL-174-Rossiter_M100/2021-11-07_19-19-31_flir',
#  'val/2021-11-08_FIRE-SGL-174-Rossiter_M100/2021-11-07_19-19-36_flir',
#  'val/2021-11-08_FIRE-SGL-174-Rossiter_M100/2021-11-07_19-19-54_flir',
#  'val/2021-11-08_FIRE-SGL-174-Rossiter_M100/2021-11-07_19-20-26_flir',
#  'val/2022-05-11_FIRE-SGL-111-Confluence_M600/2022-04-27_00-18-06_flir',
#  'val/2022-05-11_FIRE-SGL-111-Confluence_M600/2022-04-27_00-18-06_seek',
#  'val/2022-05-11_FIRE-SGL-111-Confluence_M600/2022-04-27_00-18-47_flir',
#  'val/2022-05-11_FIRE-SGL-111-Confluence_M600/2022-04-27_00-18-47_seek',
#  'val/2022-05-11_FIRE-SGL-111-Confluence_M600/2022-04-27_00-24-53_flir',
#  'val/2022-05-11_FIRE-SGL-111-Confluence_M600/2022-04-27_00-24-53_seek',
#  'val/2022-11-08_FIRE-SGL-108-Reade-Township_M600/2022-11-08_13-15-55_seek',
#  'val/2022-11-08_FIRE-SGL-108-Reade-Township_M600/2022-11-08_14-13-12_seek',
#  'val/2022-11-08_FIRE-SGL-108-Reade-Township_M600/2022-11-08_14-40-21_seek']

# %%
run = list_of_runs[1]

# %%
run
# Out:
# 'val/2021-11-08_FIRE-SGL-174-Rossiter_M100/2021-11-07_19-19-36_flir'

# %%
def count_detections_per_class(path):
    num_v = 0
    num_h = 0
    with open(path, "r") as f:
        lines = f.readlines()
        # if len(lines) == 0:
        #     print(lines)
        #     raise ValueError(f"File {path} is empty")
        for line in lines:
            if "v" in line or "c" in line:
                num_v += 1
            elif "h" in line:
                num_h += 1
            else:
                print(lines)
                raise ValueError(f"File {path} has no class")
    return num_v, num_h

# %%
def count_run_stats(run):
    num_total = 0
    num_labeled = 0
    total_num_v = 0
    total_num_h = 0
    width, height = 0, 0
    for f in os.listdir(run):
        if "label" in f:  # is label file
            num_v, num_h = count_detections_per_class(run + "/" + f)
            total_num_v += num_v
            total_num_h += num_h

            if num_v > 0 or num_h > 0:
                num_labeled += 1
        else:  # is image file
            if width == 0:  # if resolution is not set, then set it
                # find resolution from image file
                img = cv2.imread(run + "/" + f)
                width, height, _ = img.shape
            num_total += 1

    # print(f"resolution={width}, {height}")
    # print(f"{num_total=}, {num_labeled=}, {total_num_v=}, {total_num_h=}")
    # print(f"percentage labeled={num_labeled/num_total}")
    return num_total, num_labeled, total_num_v, total_num_h, width, height

# %%
# pandas dataframe to store information about each run
df = pd.DataFrame(
    columns=[
        "folder",
        "num_total",
        "num_labeled",
        "total_num_v",
        "total_num_h",
        "resolution",
    ]
)

for run in list_of_runs:
    num_total, num_labeled, total_num_v, total_num_h, width, height = count_run_stats(
        run
    )
    # folder name is the run name minus the path
    folder = run.split("/")[-1]
    df = pd.concat(
        [
            df,
            pd.DataFrame(
                {
                    "folder": folder,
                    "num_total": num_total,
                    "num_labeled": num_labeled,
                    "total_num_v": total_num_v,
                    "total_num_h": total_num_h,
                    "resolution": f"{width}x{height}",
                },
                index=[0],
            ),
        ],
        ignore_index=True,
    )

df.head()
# Out:
#                      folder num_total num_labeled total_num_v total_num_h  \
# 0  2021-11-07_19-19-31_flir        55           4           4          17
# 1  2021-11-07_19-19-36_flir        70           5           8           3
# 2  2021-11-07_19-19-54_flir         7           1           0           1
# 3  2021-11-07_19-20-26_flir        23           8           0          17
# 4  2022-04-27_00-18-06_flir       146           2           2           0
#
#   resolution
# 0    512x640
# 1    512x640
# 2    512x640
# 3    512x640
# 4    512x640

# %%
# find percentage of labeled images
df["percentage_labeled"] = df["num_labeled"] / df["num_total"] * 100
# find total percentage of labeled images
total_labeled = df["num_labeled"].sum() / df["num_total"].sum()
print(f"Total percent labelled: {total_labeled * 100} %")
# plot percentage of labeled images vs folder. y scale is 0 to 100
df.plot(
    x="folder",
    y="percentage_labeled",
    kind="bar",
    figsize=(10, 5),
    ylim=(0, 100),
    title="Percentage of Labeled Images",
    ylabel="Percentage Labeled",
    xlabel="Folder",
)
plt.legend(["Percentage Labeled"])
df.head()
# Out:
# Total percent labelled: 29.604628736740597 %
#                      folder num_total num_labeled total_num_v total_num_h  \
# 0  2021-11-07_19-19-31_flir        55           4           4          17
# 1  2021-11-07_19-19-36_flir        70           5           8           3
# 2  2021-11-07_19-19-54_flir         7           1           0           1
# 3  2021-11-07_19-20-26_flir        23           8           0          17
# 4  2022-04-27_00-18-06_flir       146           2           2           0
#
#   resolution percentage_labeled
# 0    512x640           7.272727
# 1    512x640           7.142857
# 2    512x640          14.285714
# 3    512x640          34.782609
# 4    512x640           1.369863

# %%
# plot number of vehicles and humans vs folder
# legend is number of vehicles and humans
df.plot(
    x="folder",
    y=["total_num_v", "total_num_h"],
    kind="bar",
    figsize=(10, 5),
    title="Number of Vehicles & Humans",
    ylabel="Number of Detections",
    xlabel="Folder",
    legend=True,
)
plt.legend(["Vehicles", "Humans"])

# find total number of vehicles and humans
total_num_v = df["total_num_v"].sum()
total_num_h = df["total_num_h"].sum()
print(f"Total number of vehicles: {total_num_v}")
print(f"Total number of humans: {total_num_h}")
# Out:
# Total number of vehicles: 798
# Total number of humans: 205

# %%
# find total number of 240x320 images
total_240x320 = df[df["resolution"] == "240x320"]["num_total"].sum()

# find total number of 512x640 images
total_512x640 = df[df["resolution"] == "512x640"]["num_total"].sum()

print(f"Total number of 240x320 images: {total_240x320}")
print(f"Total number of 512x640 images: {total_512x640}")

# plot number of 240x320 and 512x640 images calculated above with x,y labels and title
plt.bar(["240x320", "512x640"], [total_240x320, total_512x640])
plt.title("Number of Images by Resolution")
plt.xlabel("Resolution")
plt.ylabel("Number of Images")

# find total number of 240x320 labeled images
total_240x320_labeled = df[df["resolution"] == "240x320"]["num_labeled"].sum()

# find total number of 512x640 labeled images
total_512x640_labeled = df[df["resolution"] == "512x640"]["num_labeled"].sum()

print(f"Total number of 240x320 labeled images: {total_240x320_labeled}")
print(f"Total number of 512x640 labeled images: {total_512x640_labeled}")

# plot number of 240x320 and 512x640 labeled images calculated above with x,y labels and title
plt.bar(["240x320", "512x640"], [total_240x320_labeled, total_512x640_labeled])
# Out:
# Total number of 240x320 images: 521
# Total number of 512x640 images: 516
# Total number of 240x320 labeled images: 185
# Total number of 512x640 labeled images: 122
# <BarContainer object of 2 artists>
